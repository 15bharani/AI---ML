# %%
# Question 4: Customer Segmentation using K-Means
# Description: Use K-Means clustering for customer segmentation on a dataset that contains data about customer purchases.
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Annual_Spending': [20000, 22000, 34000, 45000, 19000, 13000, 50000, 30000],
    'Visit_Frequency': [10, 8, 15, 12, 7, 5, 18, 10]
})

kmeans = KMeans(n_clusters=3)
data['Segment'] = kmeans.fit_predict(data)

plt.scatter(data['Annual_Spending'], data['Visit_Frequency'], c=data['Segment'], cmap='viridis')
plt.title("Customer Segmentation using K-Means")
plt.xlabel("Annual Spending")
plt.ylabel("Visit Frequency")
plt.show()
